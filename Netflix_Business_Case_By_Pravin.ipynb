# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings #to ignore the warnings & make our code more representable
warnings.filterwarnings("ignore")

# %%
# !gdown 1t9iXWOY-nxsw-kCMlphRiQZ0tT0gFsVb
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1t9iXWOY-nxsw-kCMlphRiQZ0tT0gFsVb
# To: /content/netflix.csv
# 100% 3.40M/3.40M [00:00<00:00, 211MB/s]

# %%
df = pd.read_csv("netflix.csv")

# %%
# Display first 5 rows of the dataset
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#Display last 5 rows of the dataset
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
# Checking the no. of rows and columns of dataset
df.shape
# Out:
# (8807, 12)

# %%
#to check the data types of all columns and count of values in particular column.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# Insights:- From the above output, it shows that, data has total of 12 colomns. Here mostly columns has object(string) Data types. One Column has integer Data types.We can also observed that some columns has missing data.

# %%
#to find statistical summary of numerical type data
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# Insights:-
# From the above output I will say that:-
#
# 1.   Total 8807 items vailable on Netflix.
# 2.   Standard Deviation is around 8.82 year
# 3.   Minimum year is 1925, maximum year is 2021 and mean year is 2014.
# 4.   25% is 2013, 50% is 2017 and 75% 2019 year

# %%
#to find statistical summary of categorical type data
df.describe(include = object)
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added rating  duration  \
# count                 7982           7976             8797   8803      8804
# unique                7692            748             1767     17       220
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    19           2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# ...

# %% [markdown]
# Insights:- From the categorical data output we have following detils:-
#
#
# 1.   Show_id and Title are the unique.
# 2.   Rajiv Chilaka holds the top position on the director list.
# 3.   David Attenborough holds the top position on the cast list.
# 4.   United States have the maximum items avilable.

# %%
# to find Duplicate value
df.duplicated().value_counts()
# Out:
# False    8807
# Name: count, dtype: int64

# %% [markdown]
# **Insights:-** no duplicate value available in given data.

# %%
#to find missing value
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# **Insights:-** From the above output mostly missing data are in director (2634), country(831) and cast(825) columns.

# %%
#Visualization of Missing value
import missingno as msno
color = ['red','red','red','red','red','red','black','black','black','black','black','black']
msno.bar(df,sort = 'descending',color = color)
plt.title('Visualization of Missing value')
plt.show()

# %% [markdown]
# Insights:- Here Red shows no missing values & Black shows missing values in descending order.

# %%
# Handeling with missing Value

# %% [markdown]
# 1. **Director Column** - 2634 missing values hence filling it with 'NA'
#
# 2. **Country Column** - 831 missing values hence filling it with 'NA'
#
# 3. **Cast Column** - 825 missing values hence filling it with 'NA'
#
# 4. **Date Added Column**- 10 missing values hence I have drop the record.
#
# 5. **Rating & Duration Column** - since here are very less missing values so leave this as it is.

# %%
#Fillling 'NA'(Not Available) in the missing values
df[["director","cast","country"]] = df[["director","cast","country"]].fillna("NA")

# %%
# Dropping rows with missing values   like date_added(10), rating(4) and duration(3)
df.dropna(inplace=True)

# %% [markdown]
# **Comparison of tv shows vs. movies.**

# %%
# Showing the deatils of TV Show & Movies
type_counts = df['type'].value_counts()
type_counts
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %% [markdown]
# **Comparison of tv shows vs. movies.**

# %%
# Comparison of tv shows vs. movies.

labels = type_counts.index
sizes = type_counts.values
color = ['red','black']

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=60,colors=color,shadow=True,textprops={'color': 'white'} )
plt.title('Comparison of Movies vs. TV Shows')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# **Insights:-** Netflix collection of movies is substantially larger than its TV show offerings, which suggests a more comprehensive movie catalog for the streaming platform.

# %% [markdown]
# **Top 10 Countries Where Netflix is Popular**

# %%
# Find value counts
country_counts = df['country'].value_counts()

# Select the top 10 countries
top_10_country = country_counts.head(10)
top_10_country
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %%
# Plot the top 10 countries
plt.figure(figsize=(12, 8))
colors = ['#b20710'] + ['#221f1f'] * (len(top_10_country) - 1)
bar_plot = sns.barplot(x=top_10_country.index, y=top_10_country.values, palette=colors)

plt.xlabel('Country')
plt.ylabel('Number of Titles')
plt.title('Top 10 Countries Where Netflix is Popular')

# Add count values on top of each bar
for index, value in enumerate(top_10_country.values):
    bar_plot.text(index, value, str(value), ha='center', va='bottom')

plt.show()

# %% [markdown]
# **Insights:-** This chart represents that United States is the top country where Netflix is popular following by India, UK, Japan and so on.
#
#
# **Recommendation:-** Netflix should focus on acquiring more content streaming rights in additional countries, as their library varies and changes over time, and not all content is available in every country

# %% [markdown]
# **Top 10 Most Popular Actors**

# %%
# Here thorugh  unnesting find the populer actor and leaving the NA data
cast_df = df[["title", "cast"]]
cast_df["unnested_cast"] = cast_df ["cast"].apply(lambda x: str(x).split(", "))
cast_df = cast_df.explode("unnested_cast")
top_10_actor=cast_df.unnested_cast.value_counts()[1:11]
top_10_actor
# Out:
# unnested_cast
# Anupam Kher         43
# Shah Rukh Khan      35
# Julie Tejwani       33
# Naseeruddin Shah    32
# Takahiro Sakurai    32
# Rupa Bhimani        31
# Akshay Kumar        30
# Om Puri             30
# Yuki Kaji           29
# Amitabh Bachchan    28
# Name: count, dtype: int64

# %%
# Plot the top 10 Actor
plt.figure(figsize=(16, 8))
colors = ['#b20710'] + ['#221f1f'] * (len(top_10_actor) - 1)
bar_plot = sns.barplot(x=top_10_actor.index, y=top_10_actor.values, palette=colors)

plt.xlabel('Actor Name')
plt.ylabel('Movie / TV Show Count')
plt.title('Top 10 Actor Most Popular')

# Add count values on top of each bar
for index, value in enumerate(top_10_actor.values):
    bar_plot.text(index, value, str(value), ha='center', va='bottom')

plt.show()

# %% [markdown]
# **Insights:-** This chart represents that Anupam Kher is the most popular actor following by Shah Rukh Khan, Julie Tejwani and so on.
#
# **Recommendation:-** Netflix should partner with these actors to produce additional Movies/TV shows.

# %% [markdown]
# **Top 10 Most Popular Directors**

# %%
# Here thorugh  unnesting find the populer director and leaving the NA data
cast_df = df[["title", "director"]]
cast_df["unnested_director"] = cast_df ["director"].apply(lambda x: str(x).split(", "))
cast_df = cast_df.explode("unnested_director")
top_10_director=cast_df.unnested_director.value_counts()[1:11]
top_10_director
# Out:
# unnested_director
# Rajiv Chilaka          22
# Jan Suter              21
# Raúl Campos            19
# Suhas Kadav            16
# Marcus Raboy           16
# Jay Karas              15
# Cathy Garcia-Molina    13
# Martin Scorsese        12
# Jay Chapman            12
# Youssef Chahine        12
# Name: count, dtype: int64

# %%
# Plot the top 10 Director
plt.figure(figsize=(16, 8))
colors = ['#b20710'] + ['#221f1f'] * (len(top_10_director) - 1)
bar_plot = sns.barplot(x=top_10_director.index, y=top_10_director.values, palette=colors)

plt.xlabel('Director Name')
plt.ylabel('Movie / TV Show Count')
plt.title('Top 10 Director')

# Add count values on top of each bar
for index, value in enumerate(top_10_director.values):
    bar_plot.text(index, value, str(value), ha='center', va='bottom')

plt.show()

# %% [markdown]
# **Insights:-** Rajiv Chilaka is the most popular director, followed by Jan Suter, Raul Campos, and others.
#
# **Recommendation:-** Netflix should collaborate with these directors to create more films and TV shows.

# %% [markdown]
# **what content is available in different countries**

# %%
# for claculate county with movie details
df_movie = df[df['type'] == 'Movie']
df_movie = df_movie.groupby('country')['title'].nunique().sort_values(ascending = False).reset_index().loc[0:10]
df_movie = df_movie.drop(2)
df_movie
# Out:
#            country  title
# 0    United States   2058
# 1            India    893
# 3   United Kingdom    206
# 4           Canada    122
# 5            Spain     97
# 6            Egypt     92
# 7          Nigeria     86
# 8        Indonesia     77
# 9           Turkey     76
# 10           Japan     76

# %%
#setting the plot style
fig,ax = plt.subplots(figsize = (15,6))
color_map = ['black' for i in range(10)]
color_map[0] = '#b20710'

#creating the plot
ax.bar(df_movie['country'],df_movie['title'],color = color_map)

#adding valuecounts
for i in df_movie.index:
    ax.text(df_movie.loc[i,'country'],df_movie.loc[i,'title'] + 75, df_movie.loc[i,'title'])

#customizing the x-axis labels
ax.set_xticklabels(df_movie['country'],fontweight = 'bold',fontfamily='serif')

#removing the axis lines
for s in ['top','left','right']:
    ax.spines[s].set_visible(False)

#adding title to the visual
ax.set_title('Top 10 Movie Producing Countries on Netflix')


plt.show()

# %%
# for claculate county with TV Show details
df_tv = df[df['type'] == 'TV Show']
df_tv = df_tv.groupby('country')['title'].nunique().sort_values(ascending = False).reset_index().loc[0:10]
df_tv = df_tv.drop(1)
df_tv
# Out:
#            country  title
# 0    United States    760
# 2   United Kingdom    213
# 3            Japan    169
# 4      South Korea    158
# 5            India     79
# 6           Taiwan     68
# 7           Canada     59
# 8           France     49
# 9            Spain     48
# 10       Australia     48

# %%
#setting the plot style
fig,ax = plt.subplots(figsize = (17,6))

color_map = ['black' for i in range(10)]
color_map[0] = '#b20710'

#creating the plot
ax.bar(df_tv['country'],df_tv['title'],color = color_map)

#adding valuecounts
for i in df_tv.index:
    ax.text(df_tv.loc[i,'country'],df_tv.loc[i,'title'] + 25, df_tv.loc[i,'title'])

#customizing the x-axis labels
ax.set_xticklabels(df_tv['country'],fontweight = 'bold')

#removing the axis lines
for s in ['top','left','right']:
    ax.spines[s].set_visible(False)

#adding title to the visual
ax.set_title('Top 10 TV Shows Producing Countries on Netflix')
plt.show()

# %% [markdown]
# **Insights:- ** From the above output we say that US is top Country for Producing TV Show and Movies. Indian's prefer to watch movies over TV shows, on contrary South koreans perfer Tv shows over movies.
#
# **Recommendation:-**
# To explore collaborations and partnerships with content creators, production houses, and talent from the top countries, Netflix can delve into the interconnected web of international collaborations in the scientific and research domain.

# %%
# Now we Merge TV SHOW vs MOVIE

#calculate overall content count
total_cnt = df.groupby('country')['title'].nunique().sort_values(ascending  = False).reset_index().loc[0:8]

#total_cnt
total_cnt = total_cnt.drop(2)

# calculate split between tv-show and movies
df_merge = pd.merge(total_cnt,df_movie, on = 'country', how = 'left')
df_merge = pd.merge(df_merge,df_tv, on = 'country',how = 'left')

#renaming the columns
df_merge.rename(columns = {'title_x':'Total_Count','title_y':'Movie_Count','title':'TV_Show_Count'},inplace = True)

#filling the uncaptured information
df_merge['Movie_Count'].fillna(df_merge['Total_Count']-df_merge['TV_Show_Count'],inplace = True)
df_merge['TV_Show_Count'].fillna(df_merge['Total_Count']-df_merge['Movie_Count'],inplace = True)

#calculating the %split between movies and tv-shows
df_merge['Movie%'] = round((df_merge['Movie_Count']/df_merge['Total_Count'])*100)
df_merge['TV%'] = round((df_merge['TV_Show_Count']/df_merge['Total_Count'])*100)

#changing the data-type of columns to int
for i in df_merge.columns[2:]:
    df_merge[i] = df_merge[i].astype('int')

#sorting the based on movie %
df_merge = df_merge.sort_values(by= 'Movie%')
df_merge
# Out:
#           country  Total_Count  Movie_Count  TV_Show_Count  Movie%  TV%
# 4     South Korea          199           41            158      21   79
# 3           Japan          245           76            169      31   69
# 2  United Kingdom          419          206            213      49   51
# 7          France          124           75             49      60   40
# 5          Canada          181          122             59      67   33
# 6           Spain          145           97             48      67   33
# 0   United States         2818         2058            760      73   27
# 1           India          972          893             79      92    8

# %%
#setting the plot
fig,ax = plt.subplots(figsize = (15,8))

# visual of plot
ax.barh(df_merge['country'],width = df_merge['Movie%'],color = '#b20710')
ax.barh(df_merge['country'],width = df_merge['TV%'],left = df_merge['Movie%'],color ='#221f1f')
ax.set(xlim=(0,100))

#customizing ticks
ax.set_xticks([])
ax.set_yticklabels(df_merge['country'],fontweight = 'bold',fontfamily='serif')

#adding % values in the bars
for i in df_merge.index:
    ax.text((df_merge.loc[i,'Movie%'])/2,df_merge.loc[i,'country'],f"{df_merge.loc[i,'Movie%']}%",
            va = 'center', ha='center',fontsize=15, fontweight='light', fontfamily='serif',color='white')

    ax.text((df_merge.loc[i,'Movie%'] + (df_merge.loc[i,'TV%']/2)),df_merge.loc[i,'country'],f"{df_merge.loc[i,'TV%']}%",
            va = 'center', ha='center',fontsize=15, fontweight='light', fontfamily='serif',color='white')

#removing the axis lines
for s in ['top','left','right','bottom']:
    ax.spines[s].set_visible(False)

#adding title to the visual
ax.set_title('Countries with Movie & TV Show split',)

#adding legend
ax.legend(['Movie','TV Show'],loc = (0.75,1),ncol = 2,fontsize = 13)

plt.show()

# %% [markdown]
# **Insights:-**
#
#
# 1.   India has the highest percentage of movies (92%) among all the countries, which may indicate a high demand for movies.
# 2.   India,US,Spain,Canada and France countries pepole wathch movies compare to TV Show
# 3.   UK, Japan, Sk countries pepople watch TV Show compare to movies
#
# Recommendation:- To explore collaborations and partnerships with content creators, production houses, and talent from the top countries, Netflix can delve into the interconnected web of international collaborations in the scientific and research domain.

# %% [markdown]
# **What is the best time to launch a TV show?**

# %%
# best month to release the Tv show and movie
# removing extra space from date_added column
df['date_added']=df['date_added'].str.strip()

# converting date_added to datetime column
df['date_added'] = pd.to_datetime(df['date_added'])

#adding new columns
df['year_added'] = df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month_name()
df['week_added'] = df['date_added'].dt.isocalendar().week

month = df.groupby('month_added')['type'].value_counts()
month.name = 'count'
month = month.reset_index()

#converting month_added to categorical type
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
month['month_added'] = pd.Categorical(month['month_added'], categories=months, ordered=True)

month.head()
# Out:
#   month_added     type  count
# 0       April    Movie    550
# 1       April  TV Show    214
# 2      August    Movie    519
# 3      August  TV Show    236
# 4    December    Movie    547

# %%
# fetching two different data for movies and tv shows
month_movie = month.loc[month['type'] == 'Movie'].sort_values(by = 'month_added')
month_tv = month.loc[month['type'] == 'TV Show'].sort_values(by = 'month_added')

#plot style
fig,ax = plt.subplots(figsize = (13,6))
ax.set_facecolor('#f6f5f5')

#creating plot
sns.lineplot(data = month_movie, x = 'month_added', y = 'count',marker = 'o',markersize = 10,color ='#b20710',
             label = 'Movie',ax = ax)
sns.lineplot(data = month_tv, x = 'month_added', y = 'count',marker = 'o',markersize = 10,color ='#221f1f',
             label = 'TV Show', ax = ax)

#customizing the axis ticks
ax.set_xticklabels(month_movie['month_added'],fontweight = 'bold',fontfamily='serif')

#customizing axis label
plt.xlabel(None)
plt.ylabel('Count',fontweight = 'bold',fontfamily='serif',fontsize = 12)

#customizing legend
plt.legend(loc = 'center right')

#adding the title
ax.set_title('Best Month to launch a TV show/Movie?')

plt.show()

# %% [markdown]
# **Insights:-**
#
#
# 1.  The months of July, August, October, and December record higher content upload counts, whereas February, May, and November experience comparatively lower counts.
#
# **Recommendation:-**
#
# 2.   In Xmas and new year must upload new movies or tv show.

# %% [markdown]
# **Best Day to Release a TV Show / Movie**

# %%
# find day of week
df['Day'] = df['date_added'].dt.day_name()

tv_shows = df.query('type == "TV Show"')
movies = df.query('type == "Movie"')

# Counting the number of titles per month and finding the month with the highest count
bestday_tv_shows = tv_shows.groupby('Day')['show_id'].nunique()
bestday_movies = movies.groupby('Day')['show_id'].nunique()

tvshows_day = bestday_tv_shows.idxmax()
movie_day = bestday_movies.idxmax()

print('Release the TV show Day:',tvshows_day)
print('Release the Movie Day:',movie_day)
# Out:
# Release the TV show Day: Friday
# Release the Movie Day: Friday

# %%
plt.figure(figsize = (12,9))
colors = ['#FF0000', '#CD5C5C', '#8B0000', '#800000', '#600000', '#400000', '#000000']

# Creating chart
plt.subplot(2,2,1)
plt.pie(bestday_tv_shows.values, labels = bestday_tv_shows.index, autopct='%1.1f%%',
        colors = colors, startangle=140, textprops={'color':"white"}) # Create pie chart
plt.title('Best Day to Release a TV Show')
plt.legend(loc=(1, 0.5),frameon = False )


# Creating  count plot
plt.subplot(2,2,2)
plt.pie(bestday_movies.values, labels=bestday_movies.index, autopct='%1.1f%%',
        colors = colors, startangle=140, textprops={'color':"white"}) # Create pie chart
plt.title('Best Day to Release a  Movie')
plt.legend(loc=(1, 0.5),frameon = False )
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights:-** Best Day to Release a TV Show / Movie is Friday.
#
# **Recommendation:-** Explore collaboration opportunities with influencers, other content creators, or events during the best months and day. Collaborative efforts can amplify the reach and impact of content releases.

# %% [markdown]
# **Distribution of Ratings:-**

# %%
# Top 11 Count of the occurrences of each rating
rating_counts = df['rating'].value_counts()
rating_counts.head(11)
# Out:
# rating
# TV-MA    3207
# TV-14    2160
# TV-PG     863
# R         799
# PG-13     490
# TV-Y7     334
# TV-Y      307
# PG        287
# TV-G      220
# NR         80
# G          41
# Name: count, dtype: int64

# %%
# Create a chart to visualize the ratings
plt.figure(figsize=(16, 8))
colors = ['#b20710'] + ['#221f1f'] * (len(rating_counts) - 1)
sns.barplot(x=rating_counts.values, y=rating_counts.index, palette=colors)

# Customize the plot
plt.xlabel('Rating')
plt.ylabel('Count')
plt.title('Distribution of Ratings')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %% [markdown]
# **Insights:-** the above chart helps us identify the most common rating categories and their relative frequency.

# %% [markdown]
# **How has the number of movies released per year changed over the last 20-30 years?**

# %%
plt.figure(figsize=(10, 6))
colors = ['#b20710'] + ['#221f1f'] * (len(df['release_year']) - 1
sns.boxplot(x='type', y='release_year', data=df, palette=colors)
plt.title(' Release Years by Content Type')
plt.xlabel('Type')
plt.ylabel('Release Year')
plt.show()

# %% [markdown]
# **Insights:-** More no of movies added on Netflix after 2015.
#
# **Recommendation:-** Netflix must added maximum no. of TV shows and movies.

# %%
fig,ax = plt.subplots(figsize = (10,6))
colors = ['#b20710'] + ['#221f1f'] * (len(df['release_year']) - 1)
ax.hist(df['release_year'], bins=30,color='black')#edgecolor=color_map)
plt.title('Release Years Trends')
plt.xlabel('Release Year')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Insights:- **The distribution of release years is right-skewed, showing that most of the content on Netflix is relatively new.

# %% [markdown]
# **Final Conclusion**- From the analysis and visualization that has been done, it can be concluded that movies and tv shows increase every year. Movies outperform every year than TV shows. However, TV shows also have a significant increasing trend from 2000 to 2021. Then two ratings exceed the average rating, namely the rating TV-MA and TV-14. Trend type Movies are higher than the trend type TV Shows.

# %%
# the end
